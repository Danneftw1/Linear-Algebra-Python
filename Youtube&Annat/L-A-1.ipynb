# %% [markdown]
# # Linear Algebra Basics
# - Linear algebra is all about organizing numbers into vectors and matrixes in order to implement computations.
# - All lines must remain lines for them to be linear, some lines can loot linear depending on the angle.

# %%
import numpy as np
import matplotlib.pyplot as plt


np.linspace(1,10,7)
# Out:
# array([ 1. ,  2.5,  4. ,  5.5,  7. ,  8.5, 10. ])

# %% [markdown]
# #### Vector: an ordered list of numbers'
# #### Scalar: a single number not imbedded in a list

# %%
vec = np.array([3,4,5,2])
s = 2

vec*s
# Out:
# array([ 6,  8, 10,  4])

# %%
vec2d = np.array([1,2])
s1 = 2
s2 = .5
s3 = -1


plt.plot([0, vec2d[0]], [0, vec2d[1]], 'bs-');
